# %%
from main import main
main()
# Out:
# Naive Homography 0.0084 sec
# [[-1.12313781e-03 -1.64757662e-04  9.99919585e-01]
#  [-1.05117245e-05 -1.05462483e-03  1.25622165e-02]
#  [-2.96940746e-07 -4.35706349e-08 -7.82907867e-04]]
# Naive Homography Slow computation takes 6.0127 sec
# Naive Homography Fast computation takes 0.1717 sec
# Naive Homography for imperfect matches 0.0003 sec
# [[ 5.69473545e-04  1.27553946e-04 -6.07820713e-01]
#  [ 6.08182336e-04  4.71576145e-04 -7.94073110e-01]
#  [ 9.21258229e-07  3.74324571e-07 -9.71767385e-04]]
# Naive Homography Fast computation for imperfect matches takes 0.1731 sec
# Naive Homography Test 0.4059 sec
# [0.16, 459.75]
# RANSAC Homography 0.0057 sec
# [[-1.12313781e-03 -1.64757662e-04  9.99919585e-01]
#  [-1.05117245e-05 -1.05462483e-03  1.25622165e-02]
#  [-2.96940746e-07 -4.35706350e-08 -7.82907867e-04]]
# RANSAC Homography Test 0.0000 sec
# [0.8, 5.7]
# Panorama 37.9041 sec
